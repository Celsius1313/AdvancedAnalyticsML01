# %% [markdown]
# <a href="https://colab.research.google.com/github/Celsius1313/AdvancedAnalyticsML01/blob/main/Austo_project(High_Code)_Celsio_Cosme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Foundations Project: Austo

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context
#
# In the 21st century, cars are an important mode of transportation that provides us the opportunity for personal control and autonomy. In day-to-day life, people use cars for commuting to work, shopping, visiting family and friends, etc. Research shows that more than 76% of people prevent themselves from traveling somewhere if they don't have a car. Most people tend to buy different types of cars based on their day-to-day necessities and preferences. So, it is essential for automobile companies to analyze the preference of their customers before launching a car model into the market. Austo, a UK-based automobile company aspires to grow its business into the US market after successfully establishing its footprints in the European market.
#
# In order to be familiar with the types of cars preferred by the customers and factors influencing the car purchase behavior in the US market, Austo has contracted a consulting firm. Based on various market surveys, the consulting firm has created a dataset of 3 major types of cars that are extensively used across the US market. They have collected various details of the car owners which can be analyzed to understand the automobile market of the US.
#
# ### Objective
#
# Austo's management team wants to understand the demand of the buyers and trends in the US market. They want to build customer profiles based on the analysis to identify new purchase opportunities so that they can manipulate the business strategy and production to meet certain demand levels. Further, the analysis will be a good way for management to understand the dynamics of a new market. Suppose you are a Data Scientist working at the consulting firm that has been contracted by Austo. You are given the task to create buyer's profiles for different types of cars with the available data as well as a set of recommendations for Austo. Perform the data analysis to generate useful insights that will help the automobile company to grow its business.
#
# ### Data Description
#
# austo_automobile.csv: The dataset contains buyer's data corresponding to different types of products(cars).
#
# ### Data Dictionary
#
# * Age: Age of the customer
# * Gender: Gender of the customer
# * Profession: Indicates whether the customer is a salaried or business person
# * Marital_status: Marital status of the customer
# * Education: Refers to the highest level of education completed by the customer
# * No_of_dependents: Number of dependents(partner/children/spouse) of the customer
# * Personal_loan: Indicates whether the customer availed a personal loan or not
# * House_loan: Indicates whether the customer availed house loan or not
# * Partner_working: Indicates whether the customer's partner is working or not
# * Salary: Annual Salary of the customer
# * Partner_salary: Annual Salary of the customer's partner
# * Total_salary: Annual household income (Salary + Partner_salary) of the customer's family
# * Price: Price of the car
# * Make: Car type (Hatchback/Sedan/SUV)

# %% [markdown]
# ## Importing necessary libraries

# %%
# Installing the libraries with the specified version.
# !pip install numpy==1.25.2 pandas==1.5.3 matplotlib==3.7.1 seaborn==0.13.1 -q --user

# %% [markdown]
# **Note**: *After running the above cell, kindly restart the notebook kernel and run all cells sequentially from the start again.*

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the dataset

# %%
# uncomment and run the following lines for Google Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# read the data
df = pd.read_csv(r"C:\Users\P4773\Documents\Desktop_Folder_CelsioCosme_Work\McCOMBS UNIVERSITY OF TEXAS -- PGP - AIML\HANDS-ON PROJECTS\PYTHON PROJECT\01_AUTOMOBILE_APP\austo_automobile.csv")
# returns the first 5 rows
df.head()
# Out:
#    Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   24   Male   Salaried        Married  Post Graduate                 4
# 1   28   Male   Salaried        Married  Post Graduate                 3
# 2   23   Male   Salaried        Married       Graduate                 4
# 3   26   Male   Business        Married  Post Graduate                 4
# 4   28   Male   Business        Married  Post Graduate                 4
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No        Yes             Yes   52000           25000
# 1            No        Yes              No   68000               0
# 2           Yes        Yes              No   31000               0
# 3           Yes        Yes             Yes   66000           35000
# 4           Yes         No              No   64000               0
#
#    Total_salary  Price       Make
# 0         77000  18000  Hatchback
# 1         68000  18000  Hatchback
# ...

# %%
df.tail()
# Out:
#       Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 1576   28   Male   Salaried        Married  Post Graduate                 2
# 1577   23   Male   Salaried         Single       Graduate                 2
# 1578   23   Male   Business        Married       Graduate                 4
# 1579   25   Male   Business        Married  Post Graduate                 3
# 1580   28   Male   Salaried        Married       Graduate                 4
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 1576           Yes         No              No   72000               0
# 1577           Yes        Yes              No   37000               0
# 1578           Yes        Yes             Yes   38000           28000
# 1579           Yes        Yes             Yes   58000           40000
# 1580            No        Yes             Yes   54000           40000
#
#       Total_salary  Price       Make
# 1576         72000  33000  Hatchback
# ...

# %% [markdown]
# ## Data Overview

# %%
print(
    "The Dataset have", df.shape[0], "rows and", df.shape[1], "columns"
)
# Out:
# The Dataset have 1581 rows and 14 columns

# %% [markdown]
# #### Observations:
# - In datset we have:
#     * 1581 rows
#     * 14 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1581 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1581 non-null   int64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: int64(6), object(8)
# memory usage: 173.1+ KB

# %% [markdown]
# #### Observations:
# - We have 2 differents types of data:
#     * int64;
#     * object

# %%
df.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Age               1581.0     32.211259      9.125477     22.0     25.0
# No_of_Dependents  1581.0      2.457938      0.943483      0.0      2.0
# Salary            1581.0  59732.447818  14278.642665  30000.0  51000.0
# Partner_salary    1581.0  19720.430108  19480.214404      0.0      0.0
# Total_salary      1581.0  79452.877925  24855.936043  30000.0  61000.0
# Price             1581.0  35597.722960  13633.636545  18000.0  25000.0
#
#                       50%      75%       max
# Age                  29.0     38.0      60.0
# No_of_Dependents      2.0      3.0       4.0
# Salary            59000.0  71000.0   90000.0
# Partner_salary    25000.0  38000.0   80000.0
# Total_salary      78000.0  96000.0  158000.0
# Price             31000.0  47000.0   70000.0

# %% [markdown]
# #### Observations:
#
# - Here we need to have some attention:
#     * Probably we have people with a high age (More than 50 years) but that have a car;
#     * We have some cars that are too expensive, that cost around of $ 70K.

# %%
print("Cheking null values", df.isnull().sum().sum(), end="\n")
print("Cheking na values", df.isna().sum().sum())
# Out:
# Cheking null values 0
# Cheking na values 0

# %% [markdown]
# #### Observations:
# - We don't have "na" and "null" values

# %%
df[df["Make"] == "SUV"].groupby(["Make"])[["Make"]].count().T
# Out:
# Make  SUV
# Make  237

# %% [markdown]
# #### Observations:
# - Are in total 237 SUV cars

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %%
numerical_columns = df.select_dtypes(include="int64").columns.tolist()
print("Numerical Columns:", numerical_columns, "<===> Total:", len(numerical_columns))
plt.figure(figsize=(15, 10)) # Defining all space plot subplots


for i, column in enumerate(numerical_columns):
    plt.subplot(5, 3, i+1) # Defining the number of rows and columns that the subplots will be presented
    sns.histplot(df, x=column, kde=True)

plt.tight_layout();
# Out:
# Numerical Columns: ['Age', 'No_of_Dependents', 'Salary', 'Partner_salary', 'Total_salary', 'Price'] <===> Total: 6

# %% [markdown]
# * In this plot we can see that the Partner Salary increase a lot the total salary, because we have more that 600 Partners have a salary between $30K and $40K, most cars have a price less than $33K

# %%
categorical_columns = df.select_dtypes(exclude="number").columns.tolist()
print("Non-numerical Columns:", categorical_columns, "<===> Total:", len(categorical_columns))

plt.figure(figsize=(20,25))

for i, column in enumerate(categorical_columns):
    plt.subplot(5, 4, i+1)
    sns.countplot(df, x=column, stat="percent", hue="Profession")

plt.tight_layout;
# Out:
# Non-numerical Columns: ['Gender', 'Profession', 'Marital_status', 'Education', 'Personal_loan', 'House_loan', 'Partner_working', 'Make'] <===> Total: 8

# %% [markdown]
# * Here we can see that at least 55% of Salaried people bought a car and they have preference for Hatchback vehicles

# %%
plt.figure(figsize=(20, 10))

for i, column in enumerate(numerical_columns):
    plt.subplot(3, 2, i+1)
    sns.boxplot(df, x=column, hue="Profession")

plt.tight_layout;

# %% [markdown]
# * Here we can note that the Salaried people have more chance to buy an expensive car.
# * And we can see that the **Total Salary** also the **Salary** himself for Business Man is less than the Salarieds salary.

# %% [markdown]
# #### Observations:
# * The **Histograms** show us that the *Partner Salary* increase a lot the *total salary*, because we have more that 600 Partners have a salary between **$30K and $40K**
# * The **Histograms** show us that most cars have a price less than $33K
# * The **Countplots** show that at least *55% of Salaried people* bought a car and they have preference for *Hatchback* vehicles
# * In the **Boxplots** we can note that the *Salaried people* have more chance to buy an expensive car.
# * And also in the **Boxplots**, we can see that the *Total Salary* and also the *Salary* himself, for Business Man is less than the Salarieds salary.

# %%
Hatchback = df[df["Make"] == "Hatchback"]
print("Hatchbacks with a price higher or equal to $ 27K")
Hatchback[Hatchback["Price"] >= 27000].groupby(["Make"])[["Make"]].count().T
# Out:
# Hatchbacks with a price higher or equal to $ 27K
# Make  Hatchback
# Make        390

# %% [markdown]
# #### Observations:
# * We have 390 Hatchbacks with a price higher or equal to $ 27K

# %%
Customers_with_Personal_Loan = df[df["Personal_loan"] == "Yes"]
Customers_with_Personal_Loan_Salary_Less_Than_Car = Customers_with_Personal_Loan[Customers_with_Personal_Loan["Salary"] < Customers_with_Personal_Loan["Price"]].sort_values("Price", ascending=False)

print("Are in total", Customers_with_Personal_Loan_Salary_Less_Than_Car.value_counts().sum(), "Customers that bought cars with price higher than their salaries")
# Out:
# Are in total 44 Customers that bought cars with price higher than their salaries

# %% [markdown]
# #### Observations:
# * Are in total 44 Customers that bought cars with price higher than their salaries

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df);

# %%
df_corr = df.corr(numeric_only=True)
df_corr
# Out:
#                        Age  No_of_Dependents    Salary  Partner_salary  \
# Age               1.000000         -0.157163  0.606094        0.150202
# No_of_Dependents -0.157163          1.000000 -0.043847        0.144508
# Salary            0.606094         -0.043847  1.000000        0.061943
# Partner_salary    0.150202          0.144508  0.061943        1.000000
# Total_salary      0.465891          0.088067  0.623003        0.819309
# Price             0.790466         -0.135839  0.393038        0.156154
#
#                   Total_salary     Price
# Age                   0.465891  0.790466
# No_of_Dependents      0.088067 -0.135839
# Salary                0.623003  0.393038
# Partner_salary        0.819309  0.156154
# Total_salary          1.000000  0.348164
# Price                 0.348164  1.000000

# %%
sns.heatmap(df_corr, annot=True, fmt=".2f", cbar=False)
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))
sns.lineplot(df, x="Age", y="Price", hue="Marital_status", ax=axes[0])
axes[0].set_title("Price and Age per Marital Status")
sns.lineplot(df, x="Age", y="Price", hue="Profession", ax=axes[1])
axes[1].set_title("Price and Age per Profession")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))
sns.lineplot(df, x="Age", y="Salary", hue="Marital_status", ax=axes[0])
axes[0].set_title("Salary and Age per Marital Status")
sns.lineplot(df, x="Age", y="Salary", hue="Profession", ax=axes[1])
axes[1].set_title("Salary and Age per Profession")
plt.tight_layout()
plt.show()

# %%
Customers_with_3_Or_Less_Dependents = df[df["No_of_Dependents"] <= 3]
round(Customers_with_3_Or_Less_Dependents.groupby(["Profession"])[["Price"]].mean().T, 2)
# Out:
# Profession  Business  Salaried
# Price       32830.22  37036.18

# %% [markdown]
# #### Observations:

# %%
Customers_With_2_Loans = df[(df["Personal_loan"] == "Yes") & (df["House_loan"] == "Yes")]
Customers_With_2_Loans.groupby(["Profession"])[["Price"]].sum().T
# Out:
# Profession  Business  Salaried
# Price        3931000   4837000

# %% [markdown]
# #### Observations:

# %% [markdown]
# ## Conclusion and Recommendations
#
# ### Conclusions:
#
# - Kilometers Driven: Usually shows a negative correlation with the price — the more driven, the lower the price.
#
# - Transmission Type: Manual vs. automatic can influence value based on regional preferences.
#
# - Number of Previous Owners and engine power are also significant predictors of value.
#
# - Unusual mileage values may point to data inconsistencies or maintenance concerns.
#
# - The year of manufacture is a strong indicator — newer cars tend to have higher average prices.
#
#
# ### Business Recommendations:
# - Develop a dynamic pricing tool using historical data and car features (brand, year, mileage, fuel type).
#
# - Prioritize cars that offer a better price-to-mileage ratio.
#
# - Consider automatic cars or diesel options if they offer better long-term value in region.
#
# - Pay attention to the number of previous owners as an indicator of reliability.

# %% [markdown]
# ___
